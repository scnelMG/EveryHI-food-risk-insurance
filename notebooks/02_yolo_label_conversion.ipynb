# %% [markdown]
# # YOLO 라벨 변환: 공개 검토 노트북
#
# 원본 라벨은 공개하지 않고, 클래스 인덱스를 변환하는 핵심 동작만 `src/translabel.py`로 분리했습니다. 이 노트북은 입력·출력 계약을 설명합니다.

# %% [markdown]
# ## 입력과 출력
#
# - 입력: YOLO 형식 텍스트 라벨이 있는 디렉터리
# - 처리: 각 유효 라인의 첫 번째 클래스 인덱스만 지정한 값으로 교체
# - 출력: 원본 파일명은 유지하고 별도 디렉터리에 저장
# - 원본의 빈 줄·형식이 맞지 않는 줄은 임의로 바꾸지 않습니다.

# %%
from pathlib import Path

from src.translabel import translabel

input_dir = Path("/path/to/raw-labels")
output_dir = Path("/path/to/converted-labels")
# translabel(input_dir=input_dir, target_label=0, output_dir=output_dir)

# %% [markdown]
# ## 검토 포인트
#
# 실제 라벨과 이미지 데이터는 재배포하지 않습니다. 원본 데이터를 보유한 환경에서만 마지막 호출의 주석을 해제해 사용하며, 공개 저장소에서는 변환 코드와 설정 파일을 검토하는 용도로만 사용합니다.
